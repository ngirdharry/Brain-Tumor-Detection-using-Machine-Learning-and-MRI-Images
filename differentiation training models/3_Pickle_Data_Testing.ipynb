# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import random

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name !='/device:GPU:0':
  raise SystemError("Gpu not")
print('Gpu found at {} '.format(device_name))
# Out:
# Gpu found at /device:GPU:0

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Testing
# !ls
# Out:
# /content/gdrive/My Drive/Testing
# glioma_tumor  meningioma_tumor	no_tumor  pituitary_tumor  Untitled.ipynb

# %%
#This sets the directories for the testing and training data folders, the image size, and the categories of the images.

TEST_DIR = '/content/gdrive/My Drive/Testing' # test data folder
TRAIN_DIR = '/content/gdrive/My Drive/Training' # train data folder
IMG_SIZE = 150 # image size
CATEGORIES = ["glioma_tumor","meningioma_tumor","no_tumor","pituitary_tumor"]

# %%
#This creates the testing data by iterating over the categories and adding the images to the testing_data list, after resizing them to the specified IMG_SIZE. 
#It then shuffles the data and saves it as a numpy array to the file 'test_data.npy'.

testing_data = []

def create_testing_data():
    for category in CATEGORIES: 

        path = os.path.join(TEST_DIR,category)  # create path 
        class_num = CATEGORIES.index(category)  # get the classification  

        for img in tqdm(os.listdir(path)): 
          
          img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_COLOR)  # convert to array
          new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
          testing_data.append([new_array, class_num])  # add this to our training_data
    
    random.shuffle(testing_data)
   # np.save('test_data.npy', testing_data)        

create_testing_data()
np.save('test_data.npy', testing_data) 
print(len(testing_data))

print("train")
print()

#This creates numpy arrays for the testing data (with the images in X_test and their labels in Y_test). 
# It then saves these arrays as pickled files to the files 'X_test.pickle' and 'Y_test.pickle'.
X_test = np.array([i[0] for i in testing_data]).reshape(-1,IMG_SIZE,IMG_SIZE,3)
Y_test = [i[1] for i in testing_data]

import pickle

pickle_out = open("X_test.pickle","wb")
pickle.dump(X_test, pickle_out)
pickle_out.close()

pickle_out = open("Y_test.pickle","wb")
pickle.dump(Y_test, pickle_out)
pickle_out.close()
# Out:
# ...
# 100%|██████████| 74/74 [00:34<00:00,  2.16it/s]
# /usr/local/lib/python3.9/dist-packages/numpy/lib/npyio.py:518: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# 394
# train
